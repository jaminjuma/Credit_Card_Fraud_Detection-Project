# %% [markdown]
# <a href="https://colab.research.google.com/github/jaminjuma/Credit_Card_Fraud_Detection-Project/blob/main/Creditcard_fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
